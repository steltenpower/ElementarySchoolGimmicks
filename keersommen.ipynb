# %%
from IPython.display import HTML

# This generates SVG files where red is meant to cut and black to print
# Layering them z=0,1,2 and then outside borders glued together
# (maybe a z=3 thick border is needed too, to hold moving parts in)
# Now you've created a multiplying 'machine'
#
# For both x and y negative numbers could also be added,
# like in https://raw.githubusercontent.com/steltenpower/ElementarySchoolGimmicks/master/IMG_20230328_233125596.jpg
# The resulting xy numbers could easily be adjusted for that too,
# but I haven't tried to see if there's also a way to make it work for the masking
# of + and - icons depicting xy

n=12
generateFiles=True

svgWidth=400
svgHeight=400

cs={} # Coordinate System
cs["Dx"]=0.5
cs["dx"]=-0.05
cs["Dy"]=cs["Dx"]
cs["dy"]=-0.2

textAnchor="middle"# text-anchor: start | middle | end
alignmentBaseline="middle" # alignment-baseline:
# auto | baseline | before-edge | text-before-edge | middle | central | 
# after-edge | text-after-edge | ideographic | alphabetic | 
# hanging | mathematical | top | center | bottom
fontFamily="Courier" #font-family 
fontSize="0.7" #font-size
letterSpacing="-0.1" # letter-spacing

textAlign=f' text-anchor="{textAnchor}" alignment-baseline="{alignmentBaseline}"'
font=f' font-family="{fontFamily}" font-size="{fontSize}" letter-spacing="{letterSpacing}"'
textStyle=textAlign+font
cutStyle=' stroke="red" stroke-width="0.1" fill="none"'

svgDocType ='<?xml version="1.0" standalone="no"?>\n'
svgDocType+='<!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">\n'

n1=n+1

cs["margin"]=1 # on top, left, right and bottom
cs["bottomLeft_my"]=-(cs["margin"]+(4+n1))
cs["screen_bottom_myY"]=cs["bottomLeft_my"]
cs["screen_left_myX"]=cs["bottomLeft_my"]
cs["topRight_my"]=2*n1+cs["margin"]
cs["screen_top_myY"]=cs["topRight_my"]
cs["screen_right_myX"]=cs["topRight_my"]

cs["vBwidth"]=cs["screen_right_myX"]-cs["screen_left_myX"]
cs["vBheight"]=cs["vBwidth"]
cs["vBxMin"]=cs["screen_left_myX"]

# with myY_origin and svgY_origin matching:
# screen_bottom_myY,0,screen_top_myY (upwards) gives -screen_top_myY,0,-screen_bottom_myY (downwards)
cs["vByMin"]=-cs["screen_top_myY"]
def num(i):
    return str(i)   #x numbers  # i = int(s, 16) # hex, binary, octal
def write(x,y,char):
    return f'  <text x="{x}" y="{-y}">{char}</text>\n'
def dot(x,y,ij):
    if (ij>0):
        result=write(x,y,"➕") # 💩⊕
    elif (ij<0):
        result=write(x,y,"➖") # ⊖
    else:
        result=""
    return result

svgRoot ='<svg xmlns="http://www.w3.org/2000/svg" preserveAspectRatio="xMidYMid"'
svgRoot+=f' width="{svgWidth}" height="{svgHeight}"'
svgRoot+=f' viewBox="{cs["vBxMin"]} {cs["vByMin"]} {cs["vBwidth"]} {cs["vBheight"]}">\n\n'

upsideDown ='<g transform="scale(1,-1)">\n'
visualReference ='  <rect width="1" height="1" fill="none" stroke="black" stroke-width="0.05"/>\n'
upsideDown+=visualReference

def output(id,svg):
    if generateFiles:
        filename='z'+str(id)+'keersommen.svg'
        file_object = open(filename,'w')
        fileContent=svgDocType+svg
        file_object.write(fileContent)
        file_object.close()
        #print(fileContent+'\n')
        
print("configuration complete")
# Out:
# configuration complete

# %%
svg =svgRoot
svg+=upsideDown
svg+=f'  <path{cutStyle} d="M-{n1},-{n1+4} h{3*n1} v{3*n1+4} h-{3*n1+4} v-{3*n1} h4 v-4"/>\n'
svg+='</g>\n\n\n'
svg+=f'<g transform="translate({cs["Dx"]+cs["dx"]},{-(cs["Dy"]+cs["dy"])})"{textStyle}>\n'
for i in range(0,n1):
    svg+=dot(-n1+i,-n1-3,i)         #x dots
    svg+=dot(-n1-3,-n1+i,i)         #y dots
    svg+=write(-n1+i,-n1-2,num(i))
    svg+=write(-n1-2,-n1+i,num(i))
    svg+="\n"
    for j in range(0,n1):
        svg+=dot(-n1+i,-n1+j,i*j)   #xy dots
        svg+=write(i,j,num(i*j))
svg+='</g>\n\n'
svg+="\n</svg>"
output(0,svg)
HTML(f'<html><body>{svg}</body></html>')
# Out:
# <html><body><svg xmlns="http://www.w3.org/2000/svg" preserveAspectRatio="xMidYMid" width="400" height="400" viewBox="-18 -27 45 45">
#
# <g transform="scale(1,-1)">
#   <rect width="1" height="1" fill="none" stroke="black" stroke-width="0.05"/>
#   <path stroke="red" stroke-width="0.1" fill="none" d="M-13,-17 h39 v43 h-43 v-39 h4 v-4"/>
# </g>
#
#
# <g transform="translate(0.45,-0.3)" text-anchor="middle" alignment-baseline="middle" font-family="Courier" font-size="0.7" letter-spacing="-0.1">
#   <text x="-13" y="15">0</text>
#   <text x="-15" y="13">0</text>
#
#   <text x="0" y="0">0</text>
#   <text x="0" y="-1">0</text>
#   <text x="0" y="-2">0</text>
#   <text x="0" y="-3">0</text>
#   <text x="0" y="-4">0</text>
#   <text x="0" y="-5">0</text>
#   <text x="0" y="-6">0</text>
#   <text x="0" y="-7">0</text>
#   <text x="0" y="-8">0</text>
#   <text x="0" y="-9">0</text>
#   <text x="0" y="-10">0</text>
#   <text x="0" y="-11">0</text>
#   <text x="0" y="-12">0</text>
#   <text x="-12" y="16">➕</text>
#   <text x="-16" y="12">➕</text>
#   <text x="-12" y="15">1</text>
#   <text x="-15" y="12">1</text>
#
#   <text x="1" y="0">0</text>
#   <text x="-12" y="12">➕</text>
#   <text x="1" y="-1">1</text>
#   <text x="-12" y="11">➕</text>
#   <text x="1" y="-2">2</text>
#   <text x="-12" y="10">➕</text>
#   <text x="1" y="-3">3</text>
#   <text x="-12" y="9">➕</text>
#   <text x="1" y="-4">4</text>
#   <text x="-12" y="8">➕</text>
#   <text x="1" y="-5">5</text>
#   <text x="-12" y="7">➕</text>
#   <text x="1" y="-6">6</text>
#   <text x="-12" y="6">➕</text>
#   <text x="1" y="-7">7</text>
#   <text x="-12" y="5">➕</text>
#   <text x="1" y="-8">8</text>
#   <text x="-12" y="4">➕</text>
#   <text x="1" y="-9">9</text>
#   <text x="-12" y="3">➕</text>
#   <text x="1" y="-10">10</text>
#   <text x="-12" y="2">➕</text>
#   <text x="1" y="-11">11</text>
#   <text x="-12" y="1">➕</text>
#   <text x="1" y="-12">12</text>
#   <text x="-11" y="16">➕</text>
#   <text x="-16" y="11">➕</text>
#   <text x="-11" y="15">2</text>
#   <text x="-15" y="11">2</text>
#
#   <text x="2" y="0">0</text>
#   <text x="-11" y="12">➕</text>
#   <text x="2" y="-1">2</text>
#   <text x="-11" y="11">➕</text>
#   <text x="2" y="-2">4</text>
#   <text x="-11" y="10">➕</text>
#   <text x="2" y="-3">6</text>
#   <text x="-11" y="9">➕</text>
#   <text x="2" y="-4">8</text>
#   <text x="-11" y="8">➕</text>
#   <text x="2" y="-5">10</text>
#   <text x="-11" y="7">➕</text>
#   <text x="2" y="-6">12</text>
#   <text x="-11" y="6">➕</text>
#   <text x="2" y="-7">14</text>
#   <text x="-11" y="5">➕</text>
#   <text x="2" y="-8">16</text>
#   <text x="-11" y="4">➕</text>
#   <text x="2" y="-9">18</text>
#   <text x="-11" y="3">➕</text>
#   <text x="2" y="-10">20</text>
#   <text x="-11" y="2">➕</text>
#   <text x="2" y="-11">22</text>
#   <text x="-11" y="1">➕</text>
#   <text x="2" y="-12">24</text>
#   <text x="-10" y="16">➕</text>
#   <text x="-16" y="10">➕</text>
#   <text x="-10" y="15">3</text>
#   <text x="-15" y="10">3</text>
#
#   <text x="3" y="0">0</text>
#   <text x="-10" y="12">➕</text>
#   <text x="3" y="-1">3</text>
#   <text x="-10" y="11">➕</text>
#   <text x="3" y="-2">6</text>
#   <text x="-10" y="10">➕</text>
#   <text x="3" y="-3">9</text>
#   <text x="-10" y="9">➕</text>
#   <text x="3" y="-4">12</text>
#   <text x="-10" y="8">➕</text>
#   <text x="3" y="-5">15</text>
#   <text x="-10" y="7">➕</text>
#   <text x="3" y="-6">18</text>
#   <text x="-10" y="6">➕</text>
#   <text x="3" y="-7">21</text>
#   <text x="-10" y="5">➕</text>
#   <text x="3" y="-8">24</text>
#   <text x="-10" y="4">➕</text>
#   <text x="3" y="-9">27</text>
#   <text x="-10" y="3">➕</text>
#   <text x="3" y="-10">30</text>
#   <text x="-10" y="2">➕</text>
#   <text x="3" y="-11">33</text>
#   <text x="-10" y="1">➕</text>
#   <text x="3" y="-12">36</text>
#   <text x="-9" y="16">➕</text>
#   <text x="-16" y="9">➕</text>
#   <text x="-9" y="15">4</text>
#   <text x="-15" y="9">4</text>
#
#   <text x="4" y="0">0</text>
#   <text x="-9" y="12">➕</text>
#   <text x="4" y="-1">4</text>
#   <text x="-9" y="11">➕</text>
#   <text x="4" y="-2">8</text>
#   <text x="-9" y="10">➕</text>
#   <text x="4" y="-3">12</text>
#   <text x="-9" y="9">➕</text>
#   <text x="4" y="-4">16</text>
#   <text x="-9" y="8">➕</text>
#   <text x="4" y="-5">20</text>
#   <text x="-9" y="7">➕</text>
#   <text x="4" y="-6">24</text>
#   <text x="-9" y="6">➕</text>
#   <text x="4" y="-7">28</text>
#   <text x="-9" y="5">➕</text>
#   <text x="4" y="-8">32</text>
#   <text x="-9" y="4">➕</text>
#   <text x="4" y="-9">36</text>
#   <text x="-9" y="3">➕</text>
#   <text x="4" y="-10">40</text>
#   <text x="-9" y="2">➕</text>
#   <text x="4" y="-11">44</text>
#   <text x="-9" y="1">➕</text>
#   <text x="4" y="-12">48</text>
#   <text x="-8" y="16">➕</text>
#   <text x="-16" y="8">➕</text>
#   <text x="-8" y="15">5</text>
#   <text x="-15" y="8">5</text>
#
#   <text x="5" y="0">0</text>
#   <text x="-8" y="12">➕</text>
#   <text x="5" y="-1">5</text>
#   <text x="-8" y="11">➕</text>
#   <text x="5" y="-2">10</text>
#   <text x="-8" y="10">➕</text>
#   <text x="5" y="-3">15</text>
#   <text x="-8" y="9">➕</text>
#   <text x="5" y="-4">20</text>
#   <text x="-8" y="8">➕</text>
#   <text x="5" y="-5">25</text>
#   <text x="-8" y="7">➕</text>
#   <text x="5" y="-6">30</text>
#   <text x="-8" y="6">➕</text>
#   <text x="5" y="-7">35</text>
#   <text x="-8" y="5">➕</text>
#   <text x="5" y="-8">40</text>
#   <text x="-8" y="4">➕</text>
#   <text x="5" y="-9">45</text>
#   <text x="-8" y="3">➕</text>
#   <text x="5" y="-10">50</text>
#   <text x="-8" y="2">➕</text>
#   <text x="5" y="-11">55</text>
#   <text x="-8" y="1">➕</text>
#   <text x="5" y="-12">60</text>
#   <text x="-7" y="16">➕</text>
#   <text x="-16" y="7">➕</text>
#   <text x="-7" y="15">6</text>
#   <text x="-15" y="7">6</text>
#
#   <text x="6" y="0">0</text>
#   <text x="-7" y="12">➕</text>
#   <text x="6" y="-1">6</text>
#   <text x="-7" y="11">➕</text>
#   <text x="6" y="-2">12</text>
#   <text x="-7" y="10">➕</text>
#   <text x="6" y="-3">18</text>
#   <text x="-7" y="9">➕</text>
#   <text x="6" y="-4">24</text>
#   <text x="-7" y="8">➕</text>
#   <text x="6" y="-5">30</text>
#   <text x="-7" y="7">➕</text>
#   <text x="6" y="-6">36</text>
#   <text x="-7" y="6">➕</text>
#   <text x="6" y="-7">42</text>
#   <text x="-7" y="5">➕</text>
#   <text x="6" y="-8">48</text>
#   <text x="-7" y="4">➕</text>
#   <text x="6" y="-9">54</text>
#   <text x="-7" y="3">➕</text>
#   <text x="6" y="-10">60</text>
#   <text x="-7" y="2">➕</text>
#   <text x="6" y="-11">66</text>
#   <text x="-7" y="1">➕</text>
#   <text x="6" y="-12">72</text>
#   <text x="-6" y="16">➕</text>
#   <text x="-16" y="6">➕</text>
#   <text x="-6" y="15">7</text>
#   <text x="-15" y="6">7</text>
#
#   <text x="7" y="0">0</text>
#   <text x="-6" y="12">➕</text>
#   <text x="7" y="-1">7</text>
#   <text x="-6" y="11">➕</text>
#   <text x="7" y="-2">14</text>
#   <text x="-6" y="10">➕</text>
#   <text x="7" y="-3">21</text>
#   <text x="-6" y="9">➕</text>
#   <text x="7" y="-4">28</text>
#   <text x="-6" y="8">➕</text>
#   <text x="7" y="-5">35</text>
#   <text x="-6" y="7">➕</text>
#   <text x="7" y="-6">42</text>
#   <text x="-6" y="6">➕</text>
#   <text x="7" y="-7">49</text>
#   <text x="-6" y="5">➕</text>
#   <text x="7" y="-8">56</text>
#   <text x="-6" y="4">➕</text>
#   <text x="7" y="-9">63</text>
#   <text x="-6" y="3">➕</text>
#   <text x="7" y="-10">70</text>
#   <text x="-6" y="2">➕</text>
#   <text x="7" y="-11">77</text>
#   <text x="-6" y="1">➕</text>
#   <text x="7" y="-12">84</text>
#   <text x="-5" y="16">➕</text>
#   <text x="-16" y="5">➕</text>
#   <text x="-5" y="15">8</text>
#   <text x="-15" y="5">8</text>
#
#   <text x="8" y="0">0</text>
#   <text x="-5" y="12">➕</text>
#   <text x="8" y="-1">8</text>
#   <text x="-5" y="11">➕</text>
#   <text x="8" y="-2">16</text>
#   <text x="-5" y="10">➕</text>
#   <text x="8" y="-3">24</text>
#   <text x="-5" y="9">➕</text>
#   <text x="8" y="-4">32</text>
#   <text x="-5" y="8">➕</text>
#   <text x="8" y="-5">40</text>
#   <text x="-5" y="7">➕</text>
#   <text x="8" y="-6">48</text>
#   <text x="-5" y="6">➕</text>
#   <text x="8" y="-7">56</text>
#   <text x="-5" y="5">➕</text>
#   <text x="8" y="-8">64</text>
#   <text x="-5" y="4">➕</text>
#   <text x="8" y="-9">72</text>
#   <text x="-5" y="3">➕</text>
#   <text x="8" y="-10">80</text>
#   <text x="-5" y="2"

# %%
svg=svgRoot
svg+=upsideDown
svg+='  <g transform="matrix(0,1,1,0,0,0)">\n' # wissel x,y

#slider
cuts =f'    <path{cutStyle} d="M0,0 h{n1} v{n} h-{n1} v1 h{n1} m0,-1 v{n1} h-{2*n1+3}'
cuts+=f' v-{n+n1} h2 v-1 h-1 v-{n+4} h1 v{4+n1-2} h1 v2 h{n1}"/>\n'
#border
cuts+=f'   <path{cutStyle} d="M0,0 h{n1} v-{n} h-{n1} v-5 h{2*n1} v{3*n1+4}'
cuts+=f' h-{3*n1+4} v-{3*n1} h2 m0,1 h-1 v{n}"/>\n'
svg+=cuts
svg+="  </g>\n"
svg+="</g>\n"
output(1,svg+"\n</svg>")
HTML('<html><body>'+svg+'</body></html>')
# Out:
# <html><body><svg xmlns="http://www.w3.org/2000/svg" preserveAspectRatio="xMidYMid" width="400" height="400" viewBox="-18 -27 45 45">
#
# <g transform="scale(1,-1)">
#   <rect width="1" height="1" fill="none" stroke="black" stroke-width="0.05"/>
#   <g transform="matrix(0,1,1,0,0,0)">
#     <path stroke="red" stroke-width="0.1" fill="none" d="M0,0 h13 v12 h-13 v1 h13 m0,-1 v13 h-29 v-25 h2 v-1 h-1 v-16 h1 v15 h1 v2 h13"/>
#    <path stroke="red" stroke-width="0.1" fill="none" d="M0,0 h13 v-12 h-13 v-5 h26 v43 h-43 v-39 h2 m0,1 h-1 v12"/>
#   </g>
# </g>
# </body></html>

# %%
svg=svgRoot
svg+=upsideDown
svg+=cuts
svg+="</g>\n"

svg+=f'<g transform="translate({cs["Dx"]+cs["dx"]},{-(cs["Dy"]+cs["dy"])})"{textStyle}>\n'
svg+=write(-1.5,n+n1,"KEERSOMMEN met gevoel, Roos &amp; Ruud")
svg+=write(n1-0.5,-n1,"Getal én aantal,")
svg+=write(n1-0.5,-n1-1,"zichtbaar in som.")
svg+=write(n1-0.5,-n1-2,"Ontwerp variant")
svg+=write(n1-0.5,-n1-3,"via edu.nl/...")
svg+=write(n1-0.5,-n1-4,"Voor ❀ met ♡")
svg+='</g>\n'
svg+='\n</svg>'
output(2,svg)
HTML('<html><body>'+svg+'</body></html>')
# Out:
# <html><body><svg xmlns="http://www.w3.org/2000/svg" preserveAspectRatio="xMidYMid" width="400" height="400" viewBox="-18 -27 45 45">
#
# <g transform="scale(1,-1)">
#   <rect width="1" height="1" fill="none" stroke="black" stroke-width="0.05"/>
#     <path stroke="red" stroke-width="0.1" fill="none" d="M0,0 h13 v12 h-13 v1 h13 m0,-1 v13 h-29 v-25 h2 v-1 h-1 v-16 h1 v15 h1 v2 h13"/>
#    <path stroke="red" stroke-width="0.1" fill="none" d="M0,0 h13 v-12 h-13 v-5 h26 v43 h-43 v-39 h2 m0,1 h-1 v12"/>
# </g>
# <g transform="translate(0.45,-0.3)" text-anchor="middle" alignment-baseline="middle" font-family="Courier" font-size="0.7" letter-spacing="-0.1">
#   <text x="-1.5" y="-25">KEERSOMMEN met gevoel, Roos &amp; Ruud</text>
#   <text x="12.5" y="13">Getal én aantal,</text>
#   <text x="12.5" y="14">zichtbaar in som.</text>
#   <text x="12.5" y="15">Ontwerp variant</text>
#   <text x="12.5" y="16">via edu.nl/...</text>
#   <text x="12.5" y="17">Voor ❀ met ♡</text>
# </g>
#
# </svg></body></html>
